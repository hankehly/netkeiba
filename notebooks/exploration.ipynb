# %%
from sys import path
path.insert(0, '..')

import pandas as pd
from IPython.display import display

pd.options.display.max_columns = None

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import numpy as np
np.random.seed(42)

# %%
from scripts.utils import read_netkeiba

identifier_cols = [
    'c_id',
    'r_id',
    'h_id',
    'j_id',
    't_id',
    'r_key',
    'h_key',
    'j_key',
    't_key',
    'r_date'
]

df = read_netkeiba().drop(columns=identifier_cols)

# %%
df.head()
# Out:
#    c_weight_carried  c_post_position  c_order_of_finish  \
# 0              54.0                7                  1
# 1              54.0                8                  2
# 2              54.0                4                  3
# 3              54.0                6                  4
# 4              54.0                6                  5
#
#    c_order_of_finish_lowered  c_finish_time  c_horse_weight  \
# 0                          0          109.9             514
# 1                          0          110.1             490
# 2                          0          110.4             464
# 3                          0          110.4             450
# 4                          0          110.5             426
#
#    c_horse_weight_diff  c_popularity  c_first_place_odds r_racetrack  \
# 0                   -2             1                 3.7        fuma
# 1                    0             3                 6.3        fuma
# ...

# %%
df.describe()
# Out:
#        c_weight_carried  c_post_position  c_order_of_finish  \
# count     240471.000000    240471.000000      240471.000000
# mean          55.001607         4.739669           7.862819
# std            1.779381         2.273395           4.451069
# min           47.000000         1.000000           1.000000
# 25%           54.000000         3.000000           4.000000
# 50%           55.000000         5.000000           8.000000
# 75%           56.000000         7.000000          11.000000
# max           64.000000         8.000000          18.000000
#
#        c_order_of_finish_lowered  c_finish_time  c_horse_weight  \
# count              240471.000000  240471.000000   240471.000000
# mean                    0.000046     102.141276      470.458667
# std                     0.006763      29.083785       30.170053
# min                     0.000000      53.800000      336.000000
# 25%                     0.000000      81.100000      450.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240471 entries, 0 to 240470
# Data columns (total 52 columns):
# c_weight_carried                          240471 non-null float64
# c_post_position                           240471 non-null int64
# c_order_of_finish                         240471 non-null int64
# c_order_of_finish_lowered                 240471 non-null int64
# c_finish_time                             240471 non-null float64
# c_horse_weight                            240471 non-null int64
# c_horse_weight_diff                       240471 non-null int64
# c_popularity                              240471 non-null int64
# c_first_place_odds                        240471 non-null float64
# r_racetrack                               240471 non-null object
# r_course_type                             240471 non-null object
# r_weather                                 240471 non-null object
# r_distance                                240471 non-null int64
# ...

# %%
df.plot.scatter('c_order_of_finish', 'c_first_place_odds', alpha=0.1)

# %%
df.plot.scatter('c_post_position', 'c_order_of_finish', alpha=0.1)

# %%
df.plot.scatter('c_order_of_finish', 'c_popularity', alpha=0.1)

# %%
df.hist(bins=25, figsize=(20, 15))
plt.tight_layout()

# %%
df['h_total_win_rate'] = df.h_total_wins/df.h_total_races

df.plot.scatter(x='h_total_win_rate', y='j_career_1st_place_rate', c='c_order_of_finish',
                cmap=plt.get_cmap('jet'), alpha=0.1, figsize=(10, 7))

# %%
from pandas.plotting import scatter_matrix

attributes = [
    'c_order_of_finish',
    'c_horse_weight',
    'c_first_place_odds',
    'r_is_winner_regional_horse_allowed',
]

scatter_matrix(df[attributes], figsize=(12, 8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1307d54a8>,
# ...
#       dtype=object)

# %%
# user rating is unreliable
df.hist('h_user_rating')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x157dffb00>]],
#       dtype=object)

# %%
# 48kgも減ったなんて。体調不良じゃないのか？
df[df.c_horse_weight_diff == df.c_horse_weight_diff.min()]
# Out:
#         c_weight_carried  c_post_position  c_order_of_finish  \
# 123948              54.0                1                 14
#
#         c_order_of_finish_lowered  c_finish_time  c_horse_weight  \
# 123948                          0           88.6             424
#
#         c_horse_weight_diff  c_popularity  c_first_place_odds r_racetrack  \
# 123948                  -48            13               171.7       tokyo
#
#        r_course_type r_weather                                      r_url  \
# 123948          dirt     sunny  http://db.netkeiba.com/race/201605030101/
#
#         r_distance r_dirt_condition r_turf_condition r_impost_category  \
# 123948        1400             good             None         age_based
#
#         r_is_non_winner_regional_horse_allowed  \
# 123948                                       0
#
#         r_is_winner_regional_horse_allowed  r_is_regional_jockey_allowed  \
# 123948                                   0                             0
#
# ...
